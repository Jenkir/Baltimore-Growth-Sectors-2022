# %%
# Import Dependencies
import pandas as pd

# %%
# Reference the file where the CSV is located
private_co_path = "BBJ_data/fastest_growing_private_090622.csv"

# Import the data into a Pandas DataFrame
fastest_growing_private_df = pd.read_csv(private_co_path)
fastest_growing_private_df
# Out:
#                            List Title Last Published Date  List Ranking  \
# 0   Fastest-Growing Private Companies      11/5/2021 0:00             1
# 1   Fastest-Growing Private Companies      11/5/2021 0:00             2
# 2   Fastest-Growing Private Companies      11/5/2021 0:00             3
# 3   Fastest-Growing Private Companies      11/5/2021 0:00             3
# 4   Fastest-Growing Private Companies      11/5/2021 0:00             4
# ..                                ...                 ...           ...
# 93  Fastest-Growing Private Companies      11/5/2021 0:00            49
# 94  Fastest-Growing Private Companies      11/5/2021 0:00            49
# 95  Fastest-Growing Private Companies      11/5/2021 0:00            49
# 96  Fastest-Growing Private Companies      11/5/2021 0:00            50
# 97  Fastest-Growing Private Companies      11/5/2021 0:00            50
#
#     Prior List Ranking        Ranking Criteria  Ranking Info  \
# ...

# %%
public_co_path = "BBJ_data/fastest_growing_public_091622.csv"

# Import the data into a Pandas DataFrame
fastest_growing_public_df = pd.read_csv(public_co_path)
fastest_growing_public_df
# Out:
#     Contact ID Last Published Date  List Ranking  Prior List Ranking  \
# 0          NaN       7/1/2022 0:00             1                 3.0
# 1    2634911.0       7/1/2022 0:00             2                 0.0
# 2    2634912.0       7/1/2022 0:00             2                 0.0
# 3     346131.0       7/1/2022 0:00             3                 5.0
# 4    2832322.0       7/1/2022 0:00             3                 5.0
# 5    2847041.0       7/1/2022 0:00             3                 5.0
# 6    2847042.0       7/1/2022 0:00             3                 5.0
# 7     348724.0       7/1/2022 0:00             4                 4.0
# 8    1066073.0       7/1/2022 0:00             4                 4.0
# 9    2812767.0       7/1/2022 0:00             4                 4.0
# 10   2817783.0       7/1/2022 0:00             4                 4.0
# 11   2832281.0       7/1/2022 0:00             4                 4.0
# 12    338261.0       7/1/2022 0:00             5                 0.0
# ...

# %%
women_co_path = "BBJ_data/fastest_growing_women-owned_091622.csv"
# Import the data into a Pandas DataFrame
fastest_growing_women_df = pd.read_csv(women_co_path)
fastest_growing_women_df
# Out:
#     Contact ID                              List Title Last Published Date  \
# 0     346783.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 1     336457.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 2     807137.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 3     807157.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 4     350715.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 5    2761276.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 6    2824537.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 7     349310.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 8     343820.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 9     345198.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# 10    346691.0  Fastest-Growing Woman-Owned Businesses       8/4/2022 0:00
# ...

# %%
women_co_path = "BBJ_data/fastest_growing_women-owned_091622.csv"
# Import the data into a Pandas DataFrame
fastest_growing_women_df = pd.read_csv(women_co_path)
fastest_growing_women_df

# %%
cybersecurity_path = "BBJ_data/largest_cybersecurity_090622.csv"
# Import the data into a Pandas DataFrame
cybersecurity_df = pd.read_csv(cybersecurity_path)
cybersecurity_df
# Out:
#                                            List Title Last Published Date  \
# 0   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 1   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 2   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 3   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 4   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 5   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 6   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 7   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 8   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 9   Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 10  Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# 11  Largest Cybersecurity Companies in Greater Bal...       9/9/2021 0:00
# ...

# %%
managed_IT_path = "BBJ_data/managed_IT_firms_090622.csv"
# Import the data into a Pandas DataFrame
managed_IT_df = pd.read_csv(managed_IT_path)
managed_IT_df
# Out:
#           List Title Last Published Date  List Ranking  Prior List Ranking  \
# 0   Managed IT Firms      6/17/2022 0:00             1                   1
# 1   Managed IT Firms      6/17/2022 0:00             2                   2
# 2   Managed IT Firms      6/17/2022 0:00             2                   2
# 3   Managed IT Firms      6/17/2022 0:00             3                   4
# 4   Managed IT Firms      6/17/2022 0:00             3                   4
# 5   Managed IT Firms      6/17/2022 0:00             3                   4
# 6   Managed IT Firms      6/17/2022 0:00             4                   5
# 7   Managed IT Firms      6/17/2022 0:00             4                   9
# 8   Managed IT Firms      6/17/2022 0:00             6                   8
# 9   Managed IT Firms      6/17/2022 0:00             6                   8
# 10  Managed IT Firms      6/17/2022 0:00             6                   8
# ...

# %%
software_dev_path = "BBJ_data/software_developers_090622.csv"
# Import the data into a Pandas DataFrame
software_dev_df = pd.read_csv(software_dev_path)
software_dev_df
# Out:
#              List Title Last Published Date  List Ranking  Prior List Ranking  \
# 0   Software Developers      6/17/2022 0:00             1                   1
# 1   Software Developers      6/17/2022 0:00             1                   1
# 2   Software Developers      6/17/2022 0:00             1                   1
# 3   Software Developers      6/17/2022 0:00             2                   2
# 4   Software Developers      6/17/2022 0:00             3                   3
# 5   Software Developers      6/17/2022 0:00             3                   3
# 6   Software Developers      6/17/2022 0:00             3                   3
# 7   Software Developers      6/17/2022 0:00             4                   5
# 8   Software Developers      6/17/2022 0:00             5                   0
# 9   Software Developers      6/17/2022 0:00             5                   0
# 10  Software Developers      6/17/2022 0:00             6                   8
# ...

# %%
top_100_private_path = "BBJ_data/top_100_private_companies_091622.csv"
# Import the data into a Pandas DataFrame
top_100_private_df = pd.read_csv(top_100_private_path)
top_100_private_df
# Out:
#             List Title Last Published Date  List Ranking  Prior List Ranking  \
# 0    Private Companies      8/19/2022 0:00             1                 1.0
# 1    Private Companies      8/19/2022 0:00             2                 2.0
# 2    Private Companies      8/19/2022 0:00             3                 3.0
# 3    Private Companies      8/19/2022 0:00             3                 3.0
# 4    Private Companies      8/19/2022 0:00             3                 3.0
# ..                 ...                 ...           ...                 ...
# 217  Private Companies      8/19/2022 0:00            99                 0.0
# 218  Private Companies      8/19/2022 0:00            99                 0.0
# 219  Private Companies      8/19/2022 0:00            99                 0.0
# 220  Private Companies      8/19/2022 0:00            99                 0.0
# 221  Private Companies      8/19/2022 0:00           100                 0.0
#
# ...
